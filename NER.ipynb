# %%
from termcolor import colored

# %%
import re

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# %%
# Load tokenizer and model from local directory
model_dir = r"E:\NER_model"  # Replace with the actual path
tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForTokenClassification.from_pretrained(model_dir)

# %%
# Create NER pipeline
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
nationalities_lst = ['اسرائيل','امريكي', 'أفغاني', 'ألباني', 'جزائري', 'أرجنتيني', 'أرميني', 'أسترالي', 'نمساوي', 'أذربيجاني', 'بحريني', 'بنغلاديشي', 'بيلاروسي', 'بلجيكي', 'بوليفي', 'بوسني', 'برازيلي', 'بلغاري', 'كندي', 'تشيلي', 'صيني', 'كولومبي', 'كوستاريكي', 'كرواتي', 'كوبي', 'تشيكي', 'دنماركي', 'دومينيكاني', 'هولندي', 'إكوادوري', 'مصري', 'سلفادوري', 'إماراتي', 'استوني', 'إثيوبي', 'فنلندي', 'فرنسي', 'جورجي', 'ألماني', 'غاني', 'يوناني', 'غواتيمالي', 'هايتي', 'هندوراسي', 'هنغاري', 'أيسلندي', 'هندي', 'إندونيسي', 'إيراني', 'عراقي', 'أيرلندي', 'إسرائيلي', 'إيطالي', 'جامايكي', 'ياباني', 'أردني', 'كازاخستاني', 'كيني', 'كويتي', 'قيرغيزستاني', 'لاتفي', 'لبناني', 'ليبي', 'ليتواني', 'لوكسمبورغي', 'مقدوني', 'ماليزي', 'مالطي', 'مكسيكي', 'مولدوفي', 'منغولي', 'مونتينيغرين', 'مغربي', 'ناميبي', 'نيبالي', 'نيوزيلندي', 'نيكاراغواي', 'نيجيري', 'نرويجي', 'عماني', 'باكستاني', 'بنمي', 'باراغواي', 'بيروفي', 'فلبيني', 'بولندي', 'برتغالي', 'قطري', 'روماني', 'روسي', 'سعودي', 'صربي', 'سنغافوري', 'سلوفاكي', 'سلوفيني', 'صومالي', 'جنوب أفريقي', 'اوكراني', 'اميركي']

# %%
text = "تتواصل اليوم الأربعاء الحرب الروسية الأوكرانية، حيث تشتعل الجبهات في ظل سعي القوات الروسية لتحقيق المزيد من المكاسب على الأرض، فيما تواصل كييف كسب الدعم الغربي، وتحاول استعادة وتيرة التسليح كما كانت قبل اندلاع حرب غزة. وفي التطورات الميدانية، تواصل القوات الروسية مهاجمة بلدة أفدييفكا شمال مقاطعة دونيتسك شرق أوكرانيا، وذلك بهدف السيطرة عليها، حيث باتت البلدة بمثابة بؤرة القتال في الوقت الحالي، فيما أعلنت القوات الجوية الأوكرانية أن الدفاعات الجوية دمرت 41 من بين 48 طائرة مسيرة أطلقتها روسيا. يأتي ذلك فيما أفادت مصادر أوكرانية أن الهجمات الروسية على مناطق شرق وجنوب أوكرانيا تسببت بسقوط قتلى وجرحى، في حين قالت وزارة الدفاع الأوكرانية إنها أسقطت مقاتلة روسية من طراز سو 24 فوق البحر الأسود كانت في طريقها لمهاجمة أوديسا ويؤكد المسؤولون الأوكرانيون حاجتهم إلى المزيد من الأسلحة لمنع الضربات الروسية من حرمان ملايين الأشخاص من التيار الكهربائي هذا الشتاء، كما حدث في العام الماضي. وحذّر البيت الأبيض، الاثنين، من أن المساعدات العسكرية التي تقدمها الولايات المتحدة لأوكرانيا قد تنخفض بشكل حاد في الأسابيع المقبلة، في ظل عدم التوصل إلى اتفاق يتعلق بالتمويل مع المعارضة الجمهورية. هذا وأعربت قناة الأميركية عن رأي مفاده أن رهان موسكو على أن الغرب سوف يرهق من دعم كييف، لديه فرصة متزايدة في النجاح. ونقلت القناة عن مساعد رئيس الولايات المتحدة للأمن القومي، جيك سوليفان قوله: نفدت أموالنا ولم يتبق وقت تقريبا جاءت تعليقات سوليفان بعد أن حذر رئيس مكتب الإدارة والميزانية في البيت الأبيض شالاندا يونغ، رئيس مجلس النواب مايك جونسون، في رسالة من أن وقف إرسال الأسلحة والمعدات الأميركية سيجعل أوكرانيا تكبو على ركبتيها في ساحة المعركة، وسيعرض ليس فقط النجاحات التي حققتها أوكرانيا للخطر، بل سيزيد احتمال تحقيق روسيا انتصارات عسكرية"

# Perform NER on the text
results = ner_pipeline(text)

# Store named entities in a list of dictionaries
named_entities = []

for result in results:
    entity_info = {
        "Entity": result['word'],
        "Label": result['entity'],
        "Score": result['score']
    }
    named_entities.append(entity_info)

# Print or process the list of dictionaries
for entity_info in named_entities:
    print(f"Entity: {entity_info['Entity']}, Label: {entity_info['Label']}, Score: {entity_info['Score']}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Entity: اليوم, Label: B-DATE, Score: 0.9934104084968567
# Entity: الاربعاء, Label: I-DATE, Score: 0.9932323694229126
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9958269000053406
# Entity: الروسية, Label: I-ORGANIZATION, Score: 0.994941234588623
# Entity: كي, Label: B-ORGANIZATION, Score: 0.9967213273048401
# Entity: ##يف, Label: B-ORGANIZATION, Score: 0.9962443113327026
# Entity: غزة, Label: B-LOCATION, Score: 0.8980979919433594
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9943727254867554
# Entity: الروسية, Label: I-ORGANIZATION, Score: 0.9925149083137512
# Entity: اف, Label: B-LOCATION, Score: 0.9958947896957397
# Entity: ##ديي, Label: B-LOCATION, Score: 0.9962104558944702
# Entity: ##ف, Label: B-LOCATION, Score: 0.9946728348731995
# Entity: ##كا, Label: B-LOCATION, Score: 0.9955630302429199
# Entity: شمال, Label: B-LOCATION, Score: 0.5476886034011841
# Entity: مقاطعة, Label: I-LOCATION, Score: 0.717849850654602
# Entity: دون, Label: B-LOCATION, Score: 0.9975630044937134
# Entity: ##يتس, Label: B-LOCATION, Score: 0.9972990155220032
# Entity: ##ك, Label: B-LOCATION, Score: 0.9971845746040344
# Entity: شرق, Label: B-LOCATION, Score: 0.9892221689224243
# Entity: اوكرانيا, Label: I-LOCATION, Score: 0.9868605732917786
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9980831146240234
# Entity: الجوية, Label: I-ORGANIZATION, Score: 0.9962444305419922
# Entity: الاوكرانية, Label: I-ORGANIZATION, Score: 0.9974059462547302
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.
# Entity: البيت, Label: B-ORGANIZATION, Score: 0.9926485419273376
# Entity: الابيض, Label: I-ORGANIZATION, Score: 0.99411940574646
# Entity: شا, Label: B-PERSON, Score: 0.9940418601036072
# Entity: ##لاند, Label: B-PERSON, Score: 0.9934032559394836
# Entity: ##ا, Label: B-PERSON, Score: 0.9938504695892334
# Entity: يونغ, Label: I-PERSON, Score: 0.9973799586296082
# Entity: مجلس, Label: B-ORGANIZATION, Score: 0.9910274147987366
# Entity: النواب, Label: I-ORGANIZATION, Score: 0.9771216511726379
# Entity: مايك, Label: B-PERSON, Score: 0.9983235001564026
# Entity: جون, Label: I-PERSON, Score: 0.9983976483345032
# Entity: ##سون, Label: I-PERSON, Score: 0.9987196922302246
# Entity: اوكرانيا, Label: B-ORGANIZATION, Score: 0.972923219203949
# Entity: اوكرانيا, Label: B-ORGANIZATION, Score: 0.9808835387229919
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.9890425801277161

# %%
# Process the list of dictionaries
combined_results = []
current_entity = {"word": "", "label": "", "score": 0.0}

for result in named_entities:
    entity_word = result["Entity"]
    label = result["Label"]
    score = result["Score"]

    # Check if the token starts with "##" and append it to the previous word
    if entity_word.startswith("##"):
        current_entity["word"] += entity_word[2:]
    else:
        # Non-continuation token, add the current entity to the results
        if current_entity["word"]:
            combined_results.append(current_entity.copy())
            current_entity = {"word": "", "label": "", "score": 0.0}

        current_entity["word"] = entity_word
        current_entity["label"] = label
        current_entity["score"] = score

# Add the last entity to the results if any
if current_entity["word"]:
    combined_results.append(current_entity.copy())

# Print or process the combined results
for result in combined_results:
    print(f"Entity: {result['word']}, Label: {result['label']}, Score: {result['score']}")
# Out:
# Entity: اليوم, Label: B-DATE, Score: 0.9934104084968567
# Entity: الاربعاء, Label: I-DATE, Score: 0.9932323694229126
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9958269000053406
# Entity: الروسية, Label: I-ORGANIZATION, Score: 0.994941234588623
# Entity: كييف, Label: B-ORGANIZATION, Score: 0.9967213273048401
# Entity: غزة, Label: B-LOCATION, Score: 0.8980979919433594
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9943727254867554
# Entity: الروسية, Label: I-ORGANIZATION, Score: 0.9925149083137512
# Entity: افدييفكا, Label: B-LOCATION, Score: 0.9958947896957397
# Entity: شمال, Label: B-LOCATION, Score: 0.5476886034011841
# Entity: مقاطعة, Label: I-LOCATION, Score: 0.717849850654602
# Entity: دونيتسك, Label: B-LOCATION, Score: 0.9975630044937134
# Entity: شرق, Label: B-LOCATION, Score: 0.9892221689224243
# Entity: اوكرانيا, Label: I-LOCATION, Score: 0.9868605732917786
# Entity: القوات, Label: B-ORGANIZATION, Score: 0.9980831146240234
# Entity: الجوية, Label: I-ORGANIZATION, Score: 0.9962444305419922
# Entity: الاوكرانية, Label: I-ORGANIZATION, Score: 0.9974059462547302
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.9890425801277161

# %%
combined_results
# Out:
# [{'word': 'اليوم', 'label': 'B-DATE', 'score': 0.9934104},
#  {'word': 'الاربعاء', 'label': 'I-DATE', 'score': 0.99323237},
#  {'word': 'القوات', 'label': 'B-ORGANIZATION', 'score': 0.9958269},
#  {'word': 'الروسية', 'label': 'I-ORGANIZATION', 'score': 0.99494123},
#  {'word': 'كييف', 'label': 'B-ORGANIZATION', 'score': 0.9967213},
#  {'word': 'غزة', 'label': 'B-LOCATION', 'score': 0.898098},
#  {'word': 'القوات', 'label': 'B-ORGANIZATION', 'score': 0.9943727},
#  {'word': 'الروسية', 'label': 'I-ORGANIZATION', 'score': 0.9925149},
#  {'word': 'افدييفكا', 'label': 'B-LOCATION', 'score': 0.9958948},
#  {'word': 'شمال', 'label': 'B-LOCATION', 'score': 0.5476886},
#  {'word': 'مقاطعة', 'label': 'I-LOCATION', 'score': 0.71784985},
#  {'word': 'دونيتسك', 'label': 'B-LOCATION', 'score': 0.997563},
#  {'word': 'شرق', 'label': 'B-LOCATION', 'score': 0.98922217},
#  {'word': 'اوكرانيا', 'label': 'I-LOCATION', 'score': 0.9868606},
#  {'word': 'القوات', 'label': 'B-ORGANIZATION', 'score': 0.9980831},
#  {'word': 'الجوية', 'label': 'I-ORGANIZATION', 'score': 0.99624443},
#  {'word': 'الاوكرانية', 'label': 'I-ORGANIZATION', 'score': 0.99740595},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.9881295},
#  {'word': 'شرق', 'label': 'B-LOCATION', 'score': 0.99080783},
#  {'word': 'وجنوب', 'label': 'I-LOCATION', 'score': 0.98105705},
#  {'word': 'اوكرانيا', 'label': 'I-LOCATION', 'score': 0.96478933},
#  {'word': 'وزارة', 'label': 'B-ORGANIZATION', 'score': 0.9980253},
#  {'word': 'الدفاع', 'label': 'I-ORGANIZATION', 'score': 0.99613947},
#  {'word': 'الاوكرانية', 'label': 'I-ORGANIZATION', 'score': 0.99694026},
#  {'word': 'سو', 'label': 'B-PRODUCT', 'score': 0.98553675},
#  {'word': '24', 'label': 'I-PRODUCT', 'score': 0.92662835},
#  {'word': 'البحر', 'label': 'B-LOCATION', 'score': 0.98712033},
#  {'word': 'الاسود', 'label': 'I-LOCATION', 'score': 0.9933107},
#  {'word': 'اوديسا', 'label': 'B-LOCATION', 'score': 0.96129894},
#  {'word': 'هذا', 'label': 'B-DATE', 'score': 0.9269963},
#  {'word': 'الشتاء', 'label': 'I-DATE', 'score': 0.7852633},
#  {'word': 'العام', 'label': 'B-DATE', 'score': 0.990035},
#  {'word': 'الماضي', 'label': 'I-DATE', 'score': 0.99136764},
#  {'word': 'البيت', 'label': 'B-ORGANIZATION', 'score': 0.99578434},
#  {'word': 'الابيض', 'label': 'I-ORGANIZATION', 'score': 0.9961355},
#  {'word': 'الاثنين', 'label': 'B-DATE', 'score': 0.9879929},
#  {'word': 'الولايات', 'label': 'B-ORGANIZATION', 'score': 0.99719304},
#  {'word': 'المتحدة', 'label': 'I-ORGANIZATION', 'score': 0.9958092},
#  {'word': 'لاوكرانيا', 'label': 'B-ORGANIZATION', 'score': 0.97499925},
#  {'word': 'موسكو', 'label': 'B-ORGANIZATION', 'score': 0.9845783},
#  {'word': 'الغرب', 'label': 'B-ORGANIZATION', 'score': 0.8167569},
#  {'word': 'كييف', 'label': 'B-ORGANIZATION', 'score': 0.9949104},
#  {'word': 'الولايات', 'label': 'B-ORGANIZATION', 'score': 0.9945199},
#  {'word': 'المتحدة', 'label': 'I-ORGANIZATION', 'score': 0.9946972},
#  {'word': 'للامن', 'label': 'I-ORGANIZATION', 'score': 0.9433097},
#  {'word': 'القومي', 'label': 'I-ORGANIZATION', 'score': 0.96214086},
#  {'word': 'جيك', 'label': 'B-PERSON', 'score': 0.9980236},
#  {'word': 'سوليفان', 'label': 'I-PERSON', 'score': 0.9986444},
#  {'word': 'سوليفان', 'label': 'B-PERSON', 'score': 0.98860675},
#  {'word': 'مكتب', 'label': 'B-ORGANIZATION', 'score': 0.92992884},
#  {'word': 'الادارة', 'label': 'I-ORGANIZATION', 'score': 0.9374211},
#  {'word': 'والميزانية', 'label': 'I-ORGANIZATION', 'score': 0.96555114},
#  {'word': 'البيت', 'label': 'B-ORGANIZATION', 'score': 0.99264854},
#  {'word': 'الابيض', 'label': 'I-ORGANIZATION', 'score': 0.9941194},
#  {'word': 'شالاندا', 'label': 'B-PERSON', 'score': 0.99404186},
#  {'word': 'يونغ', 'label': 'I-PERSON', 'score': 0.99737996},
#  {'word': 'مجلس', 'label': 'B-ORGANIZATION', 'score': 0.9910274},
#  {'word': 'النواب', 'label': 'I-ORGANIZATION', 'score': 0.97712165},
#  {'word': 'مايك', 'label': 'B-PERSON', 'score': 0.9983235},
#  {'word': 'جونسون', 'label': 'I-PERSON', 'score': 0.99839765},
#  {'word': 'اوكرانيا', 'label': 'B-ORGANIZATION', 'score': 0.9729232},
#  {'word': 'اوكرانيا', 'label': 'B-ORGANIZATION', 'score': 0.98088354},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.9890426}]

# %%
# Create an empty set
key_words = set()

for i in combined_results:
    if i["label"] != 'B-PRODUCT' and i["label"] != 'I-PRODUCT' and i["label"] != 'B-ORGANIZATION':
        key_words.add(i["word"])
    else:
        continue

# %%
print(key_words)
# Out:
# {'شمال', 'وجنوب', 'العام', 'الماضي', 'مقاطعة', 'الروسية', 'الدفاع', 'شرق', 'الابيض', 'افدييفكا', 'القومي', 'يونغ', 'جيك', 'الاوكرانية', 'اوديسا', 'مايك', 'سوليفان', 'دونيتسك', 'الاسود', 'الادارة', 'هذا', 'شالاندا', 'البحر', 'غزة', 'اليوم', 'والميزانية', 'جونسون', 'النواب', 'الجوية', 'للامن', 'الشتاء', 'المتحدة', 'اوكرانيا', 'الاثنين', 'الاربعاء'}

# %%
matched_nationalities = []

# Replace "أ" with "ا"
text = text.replace("أ", "ا")

# Replace "إ" with "ا"
text = text.replace("إ", "ا")

# Define the part of the word you want to search for
for element in nationalities_lst:
    search_part = element

    # Create a regex pattern to find the search part
    pattern = re.compile(r"\b\w*" + re.escape(search_part) + r"\w*\b")

    # Find all the matched words in the sentence
    matched_words = re.findall(pattern, text)

    # Check if any words are found
    if matched_words:
        for word in matched_words:
            matched_nationalities.append(word)
    else:
        continue

# %%
# # Replace "أ" with "ا"
# text = text.replace("أ", "ا")

# # Replace "إ" with "ا"
# text = text.replace("إ", "ا")
# # Perform NER on the text
# results = ner_pipeline(text)

# %%
# Check if the word is a nationality
for result in matched_nationalities:
    text = text.replace(result, colored(result, on_color='on_green'))

for result in combined_results:
    if result['label'] == "B-PERSON" or result['label'] == "I-PERSON":
        text = text.replace(result['word'], colored(result['word'], on_color='on_blue'))
    elif result['label'] == "B-LOCATION" or result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
    elif result['label'] == "B-ORGANIZATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_red'))
    elif result['label'] == "B-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_yellow'))
    elif result['label'] == "I-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_magenta'))
    elif result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
    elif result['label'] == "I-DATE" or result['label'] == "B-DATE":
        if result["word"] == "من":
            continue
        else:
            text = text.replace(result['word'], colored(result['word'], on_color='on_white'))
# Print or return the colored sentence
print(text)
# Out:
# تتواصل اليوم الاربعاء الحرب الروسية الاوكرانية، حيث تشتعل الجبهات في ظل سعي القوات الروسية لتحقيق المزيد من المكاسب على الارض، فيما تواصل كييف كسب الدعم الغربي، وتحاول استعادة وتيرة التسليح كما كانت قبل اندلاع حرب غزة. وفي التطورات الميدانية، تواصل القوات الروسية مهاجمة بلدة افدييفكا شمال مقاطعة دونيتسك شرق اوكرانيا، وذلك بهدف السيطرة عليها، حيث باتت البلدة بمثابة بؤرة القتال في الوقت الحالي، فيما اعلنت القوات الجوية الاوكرانية ان الدفاعات الجوية دمرت 41 من بين 48 طائرة مسيرة اطلقتها روسيا. ياتي ذلك فيما افادت مصادر اوكرانية ان الهجمات الروسية على مناطق شرق وجنوب اوكرانيا تسببت بسقوط قتلى وجرحى، في حين قالت وزارة الدفاع الاوكرانية انها اسقطت مقاتلة روسية من طراز سو 24 فوق البحر الاسود كانت في طريقها لمهاجمة اوديسا ويؤكد المسؤولون الاوكرانيون حاجتهم الى المزيد من الاسلحة لمنع الضربات الروسية من حرمان ملايين الاشخاص من التيار الكهربائي هذا الشتاء، كما حدث في العام الماضي. وحذّر البيت الابيض، الاثنين، من ان المساعدات العسكرية التي تقدمها الولايات المتحدة لاوكرانيا قد تنخفض بشكل حاد في الاسابيع المقبلة، في ظل عدم التوصل الى اتفاق يتعلق بالتمويل مع المعارضة الجمهورية. هذا واعربت قناة الاميركية عن راي مفاده ان رهان موسكو على ان الغرب سوف يرهق من دعم كييف، لديه فرصة متزايدة في النجاح. ونقلت القناة عن مساعد رئيس الولايات المتحدة للامن القومي، جيك سوليفان قوله: نفدت اموالنا ولم يتبق وقت تقريبا جاءت تعليقات سوليفان بعد ان حذر رئيس مكتب الادارة والميزانية في البيت الابيض شالاندا يونغ، رئيس مجلس النواب مايك جونسون، في رسالة من ان وقف ارسال الاسلحة والمعدات الاميركية سيجعل اوكرانيا تكبو على ركبتيها في ساحة المعركة، وسيعرض ليس فقط النجاحات التي حققتها اوكرانيا للخطر، بل سيزيد احتمال تحقيق روسيا انتصارات عسكرية

# %%
text = "في 2014، نفذت روسيا العديد من العمليات العسكرية في الأراضي الأوكرانية، بعد احتجاجات الميدان الأوروبي وعزل الرئيس الأوكراني فيكتور يانوكوفيتش، سيطر الجنود الروس على مواقع إستراتيجية وحيوية في شبه جزيرة القرم، بعد ذلك ضمّت روسيا القرم تحت سيادتها، بعد الاستفتاء في القرم، حيث صوتَ سكّان القرم لصالح الانضمام إلى روسيا الاتحادية، بحسب النتائج الرسمية، بعد ذلك تصاعدت مظاهرات الجماعات الانفصالية المؤيدة لروسيا في دونباس، مما أدى إلى حدوث صراع مسلح بين الحكومة الأوكرانية والجماعات الانفصالية المدعومة من روسيا. في شهر أغسطس، عبرت المدرعات الروسية حدود دونيتسك من عدة مواقع، اعتبر توغل الجيش الروسي مسؤولاً عن هزيمة القوات الأوكرانية في بداية سبتمبر في نوفمبر 2014، أعلن الجيش الأوكراني عن تحرك مكثف للقوات والمعدات الروسية تجاه المناطق التي يسيطر عليها الانفصاليون في الشرق الأوكراني، ، وذكرت وكالة أنباء اسوشييتد برس ان 80 مركبة عسكرية مجهولة تتحرك في المناطق التي يسيطر عليها المتمردون، ورصدت وحدة رصد خاصة تابعة لمنظمة الأمن والتعاون في أوروبا قوافل من الأسلحة الثقيلة والدبابات في الأراضي التي تسيطر عليها جمهورية دونيتسك الشعبية راصدو المنظمة كذلك لاحظوا مركبات تنقل الذخيرة وجثث الجنود عبر الحدود الروسية-الأوكرانية تحت غطاء مساعدات إنسانية. في أوائل أغسطس 2015، لاحظت وحدة الرصد تلك، أكثر من 21 مركبة تحمل الرمز العسكري الروسي للجنود الذين قتلوا في المعركة. بحسب صحيفة موسكو تايمز، حاولت روسيا تهديد وإسكات العاملين في مجال حقوق الإنسان الذين يتناولون قضية مقتل الجنود الروس في الصراع الدائر. منظمة الأمن والتعاون الأوربية أعلنت مراراً أن راصديها منعوا من الدخول إلى الأراضي التي تسيطر عليها القوات الروسية جنباً إلى جنب مع القوات الإنفصالية. أدان المجتمع الدولي والمنظمات الحقوقية مثل منظمة العفو الدولية ما فعلته روسيا في أوكرانيا، متهمة إياها بخرق القانون الدولي، وانتهاك السيادة الأوكرانية. وفرض كل من الأتحاد الأوربي والولايات المتحدة عقوبات إقتصادية على روسيا، وعلى أفراد وشركات روسية. في أكتوبر 2015، صحيفة واشنطن بوست نشرت تقريراً عن أن روسيا قامت بنقل بعض من قوات النخبة من أوكرانيا إلى سوريا لدعم الرئيس السوري بشار الأسد. في ديسمبر 2015، الرئيس الروسي فلاديمير بوتين أعترف بأن بعض ضباط المخابرات الروسية العسكرية كانوا يعملون في أوكرانيا يوم الخميس الموافق ١٠\١٠\٢٠٢٣."

# Perform NER on the text
results = ner_pipeline(text)

# Store named entities in a list of dictionaries
named_entities = []

for result in results:
    entity_info = {
        "Entity": result['word'],
        "Label": result['entity'],
        "Score": result['score']
    }
    named_entities.append(entity_info)

# Print or process the list of dictionaries
for entity_info in named_entities:
    print(f"Entity: {entity_info['Entity']}, Label: {entity_info['Label']}, Score: {entity_info['Score']}")
# Out:
# Entity: 2014, Label: B-DATE, Score: 0.9896999597549438
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.988086462020874
# Entity: قوات, Label: B-ORGANIZATION, Score: 0.6738846898078918
# Entity: النخبة, Label: I-ORGANIZATION, Score: 0.6356443166732788
# Entity: اوكرانيا, Label: B-LOCATION, Score: 0.9886705875396729
# Entity: سوريا, Label: B-LOCATION, Score: 0.9739704728126526
# Entity: بشار, Label: B-PERSON, Score: 0.9981001019477844
# Entity: الاسد, Label: I-PERSON, Score: 0.9985694885253906
# Entity: ديسمبر, Label: B-DATE, Score: 0.9965834021568298
# Entity: 2015, Label: I-DATE, Score: 0.9732505679130554
# Entity: فلاديمير, Label: B-PERSON, Score: 0.9973848462104797
# Entity: بوتين, Label: I-PERSON, Score: 0.9985792636871338
# Entity: المخابرات, Label: B-ORGANIZATION, Score: 0.62027508020401
# Entity: الروسية, Label: I-ORGANIZATION, Score: 0.6879665851593018
# Entity: اوكرانيا, Label: B-LOCATION, Score: 0.9910071492195129
# Entity: يوم, Label: B-DATE, Score: 0.9536241292953491
# Entity: الخميس, Label: I-DATE, Score: 0.718367874622345
# Entity: الموافق, Label: I-DATE, Score: 0.8685683608055115
# Entity: ١٠, Label: B-DATE, Score: 0.9235735535621643
# Entity: \, Label: I-DATE, Score: 0.9947675466537476
# Entity: ١٠, Label: I-DATE, Score: 0.9942627549171448
# Entity: \, Label: I-DATE, Score: 0.9953579306602478
# Entity: ٢٠, Label: I-DATE, Score: 0.9883800745010376
# Entity: ##٢, Label: I-DATE, Score: 0.9856062531471252
# Entity: ##٣, Label: I-DATE, Score: 0.9795219302177429

# %%
def extract_arabic_dates(text):
    # Define a regex pattern for the date format with a single slash
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, text)

    # Format the matches as "١٠\١٠\٢٠٢٣"
    formatted_dates = [f"{day}\\{month}\\{year}" for day, month, year in matches]

    return formatted_dates

# Example usage
# text = "الاجتماع سيكون يوم الخميس الموافق ١٠\١٠\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(text)

# %%
combined_results = []
current_entity = {"word": "", "label": "", "score": 0.0}

for result in named_entities:
    entity_word = result["Entity"]
    label = result["Label"]
    score = result["Score"]

    # Check if the token starts with "##" and append it to the previous word
    if entity_word.startswith("##"):
        current_entity["word"] += entity_word[2:]
    else:
        # Non-continuation token, add the current entity to the results
        if current_entity["word"]:
            combined_results.append(current_entity.copy())
            current_entity = {"word": "", "label": "", "score": 0.0}

        current_entity["word"] = entity_word
        current_entity["label"] = label
        current_entity["score"] = score

# Add the last entity to the results if any
if current_entity["word"]:
    combined_results.append(current_entity.copy())

# Print or process the combined results
for result in combined_results:
    print(f"Entity: {result['word']}, Label: {result['label']}, Score: {result['score']}")
# Out:
# Entity: 2014, Label: B-DATE, Score: 0.9896999597549438
# Entity: روسيا, Label: B-ORGANIZATION, Score: 0.
# Entity: \, Label: I-DATE, Score: 0.9953579306602478
# Entity: ٢٠٢٣, Label: I-DATE, Score: 0.9883800745010376

# %%
combined_results
# Out:
# [{'word': '2014', 'label': 'B-DATE', 'score': 0.98969996},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.95825684},
#  {'word': 'الاراضي', 'label': 'B-LOCATION', 'score': 0.9945385},
#  {'word': 'الاوكرانية', 'label': 'I-LOCATION', 'score': 0.99392796},
#  {'word': 'الميدان', 'label': 'B-LOCATION', 'score': 0.8131447},
#  {'word': 'الاوروبي', 'label': 'I-LOCATION', 'score': 0.71714854},
#  {'word': 'فيكتور', 'label': 'B-PERSON', 'score': 0.99862206},
#  {'word': 'يانوكوفيتش', 'label': 'I-PERSON', 'score': 0.9979868},
#  {'word': 'شبه', 'label': 'B-LOCATION', 'score': 0.996698},
#  {'word': 'جزيرة', 'label': 'I-LOCATION', 'score': 0.9946295},
#  {'word': 'القرم', 'label': 'I-LOCATION', 'score': 0.9941527},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.9093263},
#  {'word': 'القرم', 'label': 'B-LOCATION', 'score': 0.92517054},
#  {'word': 'القرم', 'label': 'B-LOCATION', 'score': 0.99264646},
#  {'word': 'القرم', 'label': 'B-LOCATION', 'score': 0.971847},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98436755},
#  {'word': 'الاتحادية', 'label': 'I-ORGANIZATION', 'score': 0.9046044},
#  {'word': 'لروسيا', 'label': 'B-ORGANIZATION', 'score': 0.9697374},
#  {'word': 'دونباس', 'label': 'B-LOCATION', 'score': 0.99772507},
#  {'word': 'الحكومة', 'label': 'B-ORGANIZATION', 'score': 0.98795635},
#  {'word': 'الاوكرانية', 'label': 'I-ORGANIZATION', 'score': 0.9682584},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98541033},
#  {'word': 'شهر', 'label': 'B-DATE', 'score': 0.99629456},
#  {'word': 'اغسطس', 'label': 'I-DATE', 'score': 0.9965677},
#  {'word': 'دونيتسك', 'label': 'B-LOCATION', 'score': 0.9949833},
#  {'word': 'الجيش', 'label': 'B-ORGANIZATION', 'score': 0.995139},
#  {'word': 'الروسي', 'label': 'I-ORGANIZATION', 'score': 0.99081343},
#  {'word': 'القوات', 'label': 'B-ORGANIZATION', 'score': 0.9931512},
#  {'word': 'الاوكرانية', 'label': 'I-ORGANIZATION', 'score': 0.9879488},
#  {'word': 'بداية', 'label': 'B-DATE', 'score': 0.99454653},
#  {'word': 'سبتمبر', 'label': 'I-DATE', 'score': 0.9777374},
#  {'word': 'نوفمبر', 'label': 'B-DATE', 'score': 0.9951578},
#  {'word': '2014', 'label': 'I-DATE', 'score': 0.96972823},
#  {'word': 'الجيش', 'label': 'B-ORGANIZATION', 'score': 0.996188},
#  {'word': 'الاوكراني', 'label': 'I-ORGANIZATION', 'score': 0.9957343},
#  {'word': 'الشرق', 'label': 'B-LOCATION', 'score': 0.9952808},
#  {'word': 'الاوكراني', 'label': 'I-LOCATION', 'score': 0.9967321},
#  {'word': 'وكالة', 'label': 'B-ORGANIZATION', 'score': 0.92244226},
#  {'word': 'انباء', 'label': 'I-ORGANIZATION', 'score': 0.8924115},
#  {'word': 'اسوشييتد', 'label': 'I-ORGANIZATION', 'score': 0.6681152},
#  {'word': 'برس', 'label': 'I-ORGANIZATION', 'score': 0.9946517},
#  {'word': 'لمنظمة', 'label': 'B-ORGANIZATION', 'score': 0.99610484},
#  {'word': 'الامن', 'label': 'I-ORGANIZATION', 'score': 0.9707155},
#  {'word': 'والتعاون', 'label': 'I-ORGANIZATION', 'score': 0.9879167},
#  {'word': 'اوروبا', 'label': 'I-ORGANIZATION', 'score': 0.8812748},
#  {'word': 'جمهورية', 'label': 'B-ORGANIZATION', 'score': 0.5824999},
#  {'word': 'دونيتسك', 'label': 'I-ORGANIZATION', 'score': 0.6294213},
#  {'word': 'الحدود', 'label': 'B-LOCATION', 'score': 0.71555847},
#  {'word': 'الروسية', 'label': 'I-LOCATION', 'score': 0.58223015},
#  {'word': 'الاوكرانية', 'label': 'I-LOCATION', 'score': 0.4840975},
#  {'word': 'اوايل', 'label': 'B-DATE', 'score': 0.98132724},
#  {'word': 'اغسطس', 'label': 'I-DATE', 'score': 0.9902388},
#  {'word': '2015', 'label': 'I-DATE', 'score': 0.9676867},
#  {'word': 'موسكو', 'label': 'B-ORGANIZATION', 'score': 0.9980253},
#  {'word': 'تايمز', 'label': 'I-ORGANIZATION', 'score': 0.99574286},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98703974},
#  {'word': 'منظمة', 'label': 'B-ORGANIZATION', 'score': 0.9950035},
#  {'word': 'الامن', 'label': 'I-ORGANIZATION', 'score': 0.9649765},
#  {'word': 'والتعاون', 'label': 'I-ORGANIZATION', 'score': 0.9773555},
#  {'word': 'الاوربية', 'label': 'I-ORGANIZATION', 'score': 0.98726046},
#  {'word': 'القوات', 'label': 'B-ORGANIZATION', 'score': 0.9882533},
#  {'word': 'الروسيةية', 'label': 'I-ORGANIZATION', 'score': 0.96748304},
#  {'word': 'منظمة', 'label': 'B-ORGANIZATION', 'score': 0.99643975},
#  {'word': 'العفو', 'label': 'I-ORGANIZATION', 'score': 0.9799017},
#  {'word': 'الدولية', 'label': 'I-ORGANIZATION', 'score': 0.9954411},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98075277},
#  {'word': 'اوكرانيا', 'label': 'B-LOCATION', 'score': 0.98831767},
#  {'word': 'الاتحاد', 'label': 'B-ORGANIZATION', 'score': 0.9977392},
#  {'word': 'الاوربي', 'label': 'I-ORGANIZATION', 'score': 0.99487793},
#  {'word': 'والولايات', 'label': 'B-ORGANIZATION', 'score': 0.9982658},
#  {'word': 'المتحدة', 'label': 'I-ORGANIZATION', 'score': 0.99496704},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98595387},
#  {'word': 'اكتوبر', 'label': 'B-DATE', 'score': 0.9960627},
#  {'word': '2015', 'label': 'I-DATE', 'score': 0.9829421},
#  {'word': 'واشنطن', 'label': 'B-ORGANIZATION', 'score': 0.99735403},
#  {'word': 'بوست', 'label': 'I-ORGANIZATION', 'score': 0.9950597},
#  {'word': 'روسيا', 'label': 'B-ORGANIZATION', 'score': 0.98808646},
#  {'word': 'قوات', 'label': 'B-ORGANIZATION', 'score': 0.6738847},
#  {'word': 'النخبة', 'label': 'I-ORGANIZATION', 'score': 0.6356443},
#  {'word': 'اوكرانيا', 'label': 'B-LOCATION', 'score': 0.9886706},
#  {'word': 'سوريا', 'label': 'B-LOCATION', 'score': 0.9739705},
#  {'word': 'بشار', 'label': 'B-PERSON', 'score': 0.9981001},
#  {'word': 'الاسد', 'label': 'I-PERSON', 'score': 0.9985695},
#  {'word': 'ديسمبر', 'label': 'B-DATE', 'score': 0.9965834},
#  {'word': '2015', 'label': 'I-DATE', 'score': 0.97325057},
#  {'word': 'فلاديمير', 'label': 'B-PERSON', 'score': 0.99738485},
#  {'word': 'بوتين', 'label': 'I-PERSON', 'score': 0.99857926},
#  {'word': 'المخابرات', 'label': 'B-ORGANIZATION', 'score': 0.6202751},
#  {'word': 'الروسية', 'label': 'I-ORGANIZATION', 'score': 0.6879666},
#  {'word': 'اوكرانيا', 'label': 'B-LOCATION', 'score': 0.99100715},
#  {'word': 'يوم', 'label': 'B-DATE', 'score': 0.9536241},
#  {'word': 'الخميس', 'label': 'I-DATE', 'score': 0.7183679},
#  {'word': 'الموافق', 'label': 'I-DATE', 'score': 0.86856836},
#  {'word': '١٠', 'label': 'B-DATE', 'score': 0.92357355},
#  {'word': '\\', 'label': 'I-DATE', 'score': 0.99476755},
#  {'word': '١٠', 'label': 'I-DATE', 'score': 0.99426275},
#  {'word': '\\', 'label': 'I-DATE', 'score': 0.99535793},
#  {'word': '٢٠٢٣', 'label': 'I-DATE', 'score': 0.9883801}]

# %%
# Create an empty set
key_words = set()

for i in combined_results:
    if i["label"] != 'B-PRODUCT' and i["label"] != 'I-PRODUCT' and i["label"] != 'B-ORGANIZATION' and i["label"] != "I-DATE" and i["label"] != "B-DATE":
        key_words.add(i["word"])
    else:
        continue
        
for i in dates:
    key_words.add(i)

# %%
print(key_words)
# Out:
# {'اسوشييتد', 'الاتحادية', 'بشار', 'جزيرة', 'الروسية', 'الروسي', 'الاوكراني', 'الامن', 'تايمز', 'الاوكرانية', 'والتعاون', 'اوروبا', 'بوتين', 'الروسيةية', 'يانوكوفيتش', 'الاوروبي', 'بوست', 'القرم', 'الاسد', 'الشرق', 'الدولية', 'دونيتسك', 'الاوربي', 'سوريا', 'الاوربية', 'برس', 'فيكتور', 'الحدود', '١٠\\١٠\\٢٠٢٣', 'شبه', 'دونباس', 'النخبة', 'الميدان', 'انباء', 'المتحدة', 'اوكرانيا', 'فلاديمير', 'العفو', 'الاراضي'}

# %%
matched_nationalities = []

# Replace "أ" with "ا"
text = text.replace("أ", "ا")

# Replace "إ" with "ا"
text = text.replace("إ", "ا")

# Define the part of the word you want to search for
for element in nationalities_lst:
    search_part = element

    # Create a regex pattern to find the search part
    pattern = re.compile(r"\b\w*" + re.escape(search_part) + r"\w*\b")

    # Find all the matched words in the sentence
    matched_words = re.findall(pattern, text)

    # Check if any words are found
    if matched_words:
        for word in matched_words:
            matched_nationalities.append(word)
    else:
        continue

# %%
# Check if the word is a nationality
for result in matched_nationalities:
    text = text.replace(result, colored(result, on_color='on_green'))

for result in combined_results:
    if result['label'] == "B-PERSON" or result['label'] == "I-PERSON":
        text = text.replace(result['word'], colored(result['word'], on_color='on_blue'))
    elif result['label'] == "B-LOCATION" or result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
    elif result['label'] == "B-ORGANIZATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_red'))
    elif result['label'] == "B-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_yellow'))
    elif result['label'] == "I-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_magenta'))
    elif result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
#     elif result['label'] == "I-DATE" or result['label'] == "B-DATE":
#         if result["word"] == "من":
#             continue
#         else:
#             text = text.replace(result['word'], colored(result['word'], on_color='on_white'))
            
for i in dates:
    text = text.replace(i, colored(i, on_color='on_white'))
# Print or return the colored sentence
print(text)
# Out:
# في 2014، نفذت روسيا العديد من العمليات العسكرية في الاراضي الاوكرانية، بعد احتجاجات الميدان الاوروبي وعزل الرئيس الاوكراني فيكتور يانوكوفيتش، سيطر الجنود الروس على مواقع استراتيجية وحيوية في شبه جزيرة القرم، بعد ذلك ضمّت روسيا القرم تحت سيادتها، بعد الاستفتاء في القرم، حيث صوتَ سكّان القرم لصالح الانضمام الى روسيا الاتحادية، بحسب النتائج الرسمية، بعد ذلك تصاعدت مظاهرات الجماعات الانفصالية المؤيدة لروسيا في دونباس، مما ادى الى حدوث صراع مسلح بين الحكومة الاوكرانية والجماعات الانفصالية المدعومة من روسيا. في شهر اغسطس، عبرت المدرعات الروسية حدود دونيتسك من عدة مواقع، اعتبر توغل الجيش الروسي مسؤولاً عن هزيمة القوات الاوكرانية في بداية سبتمبر في نوفمبر 2014، اعلن الجيش الاوكراني عن تحرك مكثف للقوات والمعدات الروسية تجاه المناطق التي يسيطر عليها الانفصاليون في الشرق الاوكراني، ، وذكرت وكالة انباء اسوشييتد برس ان 80 مركبة عسكرية مجهولة تتحرك في المناطق التي يسيطر عليها المتمردون، ورصدت وحدة رصد خاصة تابعة لمنظمة الامن والتعاون في اوروبا قوافل من الاسلحة الثقيلة والدبابات في الاراضي التي تسيطر عليها جمهورية دونيتسك الشعبية راصدو المنظمة كذلك لاحظوا مركبات تنقل الذخيرة وجثث الجنود عبر الحدود الروسية-الاوكرانية تحت غطاء مساعدات انسانية. في اوائل اغسطس 2015، لاحظت وحدة الرصد تلك، اكثر من 21 مركبة تحمل الرمز العسكري الروسي للجنود الذين قتلوا في المعركة. بحسب صحيفة موسكو تايمز، حاولت روسيا تهديد واسكات العاملين في مجال حقوق الانسان الذين يتناولون قضية مقتل الجنود الروس في الصراع الدائر. منظمة الامن والتعاون الاوربية اعلنت مراراً ان راصديها منعوا من الدخول الى الاراضي التي تسيطر عليها القوات الروسية جنباً الى جنب مع القوات الانفصالية. ادان المجتمع الدولي والمنظمات الحقوقية مثل منظمة العفو الدولية ما فعلته روسيا في اوكرانيا، متهمة اياها بخرق القانون الدولي، وانتهاك السيادة الاوكرانية. وفرض كل من الاتحاد الاوربي والولايات المتحدة عقوبات اقتصادية على روسيا، وعلى افراد وشركات روسية. في اكتوبر 2015، صحيفة واشنطن بوست نشرت تقريراً عن ان روسيا قامت بنقل بعض من قوات النخبة من اوكرانيا الى سوريا لدعم الرئيس السوري بشار الاسد. في ديسمبر 2015، الرئيس الروسي فلاديمير بوتين اعترف بان بعض ضباط المخابرات الروسية العسكرية كانوا يعملون في اوكرانيا يوم الخميس الموافق ١٠\١٠\٢٠٢٣.

# %%
print(key_words)
# Out:
# {'اسوشييتد', 'الاتحادية', 'بشار', 'جزيرة', 'الروسية', 'الروسي', 'الاوكراني', 'الامن', 'تايمز', 'الاوكرانية', 'والتعاون', 'اوروبا', 'بوتين', 'الروسيةية', 'يانوكوفيتش', 'الاوروبي', 'بوست', 'القرم', 'الاسد', 'الشرق', 'الدولية', 'دونيتسك', 'الاوربي', 'سوريا', 'الاوربية', 'برس', 'فيكتور', 'الحدود', '١٠\\١٠\\٢٠٢٣', 'شبه', 'دونباس', 'النخبة', 'الميدان', 'انباء', 'المتحدة', 'اوكرانيا', 'فلاديمير', 'العفو', 'الاراضي'}

# %%
import re

def extract_arabic_dates(text):
    # Define the regex pattern for the date format
    pattern = re.compile(r'(\d{1,2}\\[١-٩٠-٩]\\d{4})')

    # Search for matches in the text
    matches = re.findall(pattern, text)

    return matches

# Example usage
text = "Today's date is ٦\٦\٢٠٢٣ and tomorrow's date is ٢٣\\٦\\٢٠٢٣."
dates = extract_arabic_dates(text)

print("Dates found:", dates)
# Out:
# Dates found: []

# %%
import re

def extract_arabic_dates(text):
    # Define the regex pattern for the date format
    pattern = re.compile(r'(\d{1,2}\\[١-٩٠-٩]\\d{2,4})')

    # Search for matches in the text
    matches = re.findall(pattern, text)

    return matches

# Example usage
text = "Today's date is ٦\\٦\\٢٠٢٣ and tomorrow's date is ٢٣\\٦\\٢٠٢٣."
dates = extract_arabic_dates(text)

print("Dates found:", dates)
# Out:
# Dates found: []

# %%
import re

def extract_arabic_dates(text):
    # Define a regex pattern for the date format
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, text)

    # Format the matches as "١٠\١٠\٢٠٢٣"
    formatted_dates = [f"{day}\\{month}\\{year}" for day, month, year in matches]

    return formatted_dates

# Example usage
text = "الاجتماع سيكون يوم الخميس الموافق ١٠\\١٠\\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(text)

print("Dates found:", dates)
# Out:
# Dates found: ['١٠\\١٠\\٢٠٢٣']

# %%
import re

def extract_arabic_dates(text):
    # Define a regex pattern for the date format with a single slash
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, text)

    # Format the matches as "١٠/١٠/٢٠٢٣"
    formatted_dates = [f"{day}/{month}/{year}" for day, month, year in matches]

    return formatted_dates

# Example usage
text = "الاجتماع سيكون يوم الخميس الموافق ١٠\١٠\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(text)

dates[0]
# Out:
# '١٠/١٠/٢٠٢٣'

# %%
import re

def extract_arabic_dates(text):
    # Define a regex pattern for the date format with a single slash
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, text)

    # Reverse the order and format the matches as "٢٠٢٣/١٠/١٠"
    formatted_dates = [f"{year}/{month}/{day}" for day, month, year in matches]

    return formatted_dates

# Example usage
text = "الاجتماع سيكون يوم الخميس الموافق ١٠\١٠\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(text)

print(dates[0])
# Out:
# ٢٠٢٣/١٠/١٠

# %%
def extract_arabic_dates(text):
    # Define a regex pattern for the date format with a single slash
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, text)

    # Format the matches as "١٠\١٠\٢٠٢٣"
    formatted_dates = [f"{day}\\{month}\\{year}" for day, month, year in matches]

    return formatted_dates

# Example usage
text = " الاجتماع سيكون يوم الخميس الموافق ١٠\١٠\٢٠٢٣ في الساعة ٣ مساءً ويوم الجمعة الموافق ١١\١٠\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(text)

print(dates)
# Out:
# ['١٠\\١٠\\٢٠٢٣', '١١\\١٠\\٢٠٢٣']

# %%
for i in dates:
    print(i)
# Out:
# ١٠\١٠\٢٠٢٣
# ١١\١٠\٢٠٢٣

# %%
# import re

# # Example Arabic text with dates
# arabic_text = "تاريخ اليوم هو ١٥ مارس ٢٠٢٣ وتاريخ الغد هو ١٦ مارس ٢٠٢٣."

# # Define a regex pattern to match Arabic dates with numerals and month names
# pattern = re.compile(r'\b\d{1,2}\s(?:يناير|فبراير|مارس|أبريل|مايو|يونيو|يوليو|أغسطس|سبتمبر|أكتوبر|نوفمبر|ديسمبر)\s\d{4}\b')

# # Use the pattern to find matches
# matches = pattern.findall(arabic_text)

# # Print the matches
# print(matches)

# %%
text = "أكد وزير الخارجية السعودي، اليوم السبت، أن الأحداث المأساوية في فلسطين تحتم علينا التحرك العاجل لوقف إطلاق النار، معلناً رفض بلاده بشكل قاطع تهجير الفلسطينيين من أراضيهم. وطالب خلال كلمته في قمة السلام بالقاهرة بفتح فوري لممرات إنسانية آمنة إلى غزة، داعياً المجتمع الدولي إلى إلزام إسرائيل بالتقيد بالقانون الدولي. وقال خلال مشاركته في القمة: «نرفض محاولات التهجير القسري للفلسطينيين، وإننا نعرب عن خيبة أملنا في عجز مجلس الأمن الدولي عن اتخاذ موقف حيال الأزمة الحالية في غزة حتى الآن، ونطالب بفتح فوري لممرات إنسانية آمنة». وعبر وزير الخارجية السعودية عن أمله في أن تسهم هذه القمة في تحرك حاسم للمجتمع الدولي لإيجاد حل لهذه الأزمة، مؤكداً على «تمسك المملكة بالسلام خياراً استراتيجياً عبر الوقوف مع الشعب الفلسطيني لاستعادة حقوقه المشروعة». وقدم وزير الخارجية السعودي الشكر للرئيس المصري عبد الفتاح السيسي، وحكومة مصر، على الجهود المبذولة «لتعزيز التنسيق والتشاور الإقليمي والدولي تجاه ما نشهده من تطورات خطيرة في قطاع غزة». كان الأمير فيصل بن فرحان بن عبد الله وزير الخارجية السعودي، وصل اليوم إلى العاصمة المصرية القاهرة، لترؤس وفد المملكة المشارك في قمة القاهرة للسلام، والمنعقدة بشأن مناقشة الصراع في غزة ومحيطها، ومستقبل القضية الفلسطينية، وذلك نيابةً عن الأمير محمد بن سلمان بن عبد العزيز ولي العهد رئيس مجلس الوزراء كما شارك بوتين. ويشارك في القمة عدد من الدول والمنظمات الدولية لبحث تطورات الأوضاع الراهنة في فلسطين، والعمل على حماية المدنيين في قطاع غزة المُحاصر، والسماح بفتح ممرات آمنة، وإدخال المساعدات الإنسانية والطبية والغذائية"

# Perform NER on the text
results = ner_pipeline(text)

# Store named entities in a list of dictionaries
named_entities = []

for result in results:
    entity_info = {
        "Entity": result['word'],
        "Label": result['entity'],
        "Score": result['score']
    }
    named_entities.append(entity_info)

# Print or process the list of dictionaries
for entity_info in named_entities:
    print(f"Entity: {entity_info['Entity']}, Label: {entity_info['Label']}, Score: {entity_info['Score']}")
# Out:
# Entity: اليوم, Label: B-DATE, Score: 0.9963799118995667
# Entity: السبت, Label: I-DATE, Score: 0.9888255000114441
# Entity: فلسطين, Label: B-LOCATION, Score: 0.9975414276123047
# Entity: بالقاهرة, Label: B-LOCATION, Score: 0.9859179854393005
# Entity: غزة, Label: B-LOCATION, Score: 0.9902003407478333
# Entity: اسراييل, Label: B-ORGANIZATION, Score: 0.9913205504417419
# Entity: مجلس, Label: B-ORGANIZATION, Score: 0.9980165958404541
# Entity: الامن, Label: I-ORGANIZATION, Score: 0.9970507621765137
# Entity: الدولي, Label: I-ORGANIZATION, Score: 0.9895915389060974
# Entity: غزة, Label: B-LOCATION, Score: 0.9981685876846313
# Entity: المملكة, Label: B-ORGANIZATION, Score: 0.9865422248840332
# Entity: عبد, Label: B-PERSON, Score: 0.9935058355331421
# Entity: الفتاح, Label: I-PERSON, Score: 0.9977335929870605
# Entity: السيسي, Label: I-PERSON, Score: 0.998599112033844
# Entity: وحكومة, Label: B-ORGANIZATION, Score: 0.949418842792511
# Entity: مصر, Label: I-ORGANIZATION, Score: 0.6352948546409607
# Entity: قطاع, Label: B-LOCATION, Score: 0.9975332021713257
# Entity: غزة, Label: I-LOCATION, Score: 0.9931434392929077
# Entity: فيصل, Label: B-PERSON, Score: 0.9820374250411987
# Entity: بن, Label: I-PERSON, Score: 0.9951735138893127
# Entity: فرحا, Label: I-PERSON, Score: 0.9969156980514526
# Entity: ##ن, Label: I-PERSON, Score: 0.9940220713615417
# Entity: بن, Label: I-PERSON, Score: 0.9869469404220581
# Entity: عبد, Label: I-PERSON, Score: 0.9960505366325378
# Entity: الله, Label: I-PERSON, Score: 0.9937238097190857
# Entity: القاهرة, Label: B-LOCATION, Score: 0.9962775111198425
# Entity: المملكة, Label: B-ORGANIZATION, Score: 0.9517402648925781
# Entity: قمة, Label: B-EVENT, Score: 0.7680076956748962
# Entity: القاهرة, Label: I-EVENT, Score: 0.6746972799301147
# Entity: للسلام, Label: I-EVENT, Score: 0.7357789278030396
# Entity: غزة, Label: B-LOCATION, Score: 0.9969769716262817
# Entity: محمد, Label: B-PERSON, Score: 0.974435567855835
# Entity: بن, Label: I-PERSON, Score: 0.9938647150993347
# Entity: سلمان, Label: I-PERSON, Score: 0.996117353439331
# Entity: بن, Label: I-PERSON, Score: 0.9416683912277222
# Entity: عبد, Label: I-PERSON, Score: 0.9942849278450012
# Entity: العزيز, Label: I-PERSON, Score: 0.9739050269126892
# Entity: مجلس, Label: B-ORGANIZATION, Score: 0.9775180220603943
# Entity: الوزراء, Label: I-ORGANIZATION, Score: 0.5891041159629822
# Entity: بوتين, Label: B-PERSON, Score: 0.9936705827713013
# Entity: فلسطين, Label: B-LOCATION, Score: 0.9967458248138428
# Entity: قطاع, Label: B-LOCATION, Score: 0.9980269074440002
# Entity: غزة, Label: I-LOCATION, Score: 0.99566251039505

# %%
combined_results = []
current_entity = {"word": "", "label": "", "score": 0.0}

for result in named_entities:
    entity_word = result["Entity"]
    label = result["Label"]
    score = result["Score"]

    # Check if the token starts with "##" and append it to the previous word
    if entity_word.startswith("##"):
        current_entity["word"] += entity_word[2:]
    else:
        # Non-continuation token, add the current entity to the results
        if current_entity["word"]:
            combined_results.append(current_entity.copy())
            current_entity = {"word": "", "label": "", "score": 0.0}

        current_entity["word"] = entity_word
        current_entity["label"] = label
        current_entity["score"] = score

# Add the last entity to the results if any
if current_entity["word"]:
    combined_results.append(current_entity.copy())

# Print or process the combined results
for result in combined_results:
    print(f"Entity: {result['word']}, Label: {result['label']}, Score: {result['score']}")
# Out:
# Entity: اليوم, Label: B-DATE, Score: 0.9963799118995667
# Entity: السبت, Label: I-DATE, Score: 0.9888255000114441
# Entity: فلسطين, Label: B-LOCATION, Score: 0.9975414276123047
# Entity: بالقاهرة, Label: B-LOCATION, Score: 0.9859179854393005
# Entity: غزة, Label: B-LOCATION, Score: 0.9902003407478333
# Entity: اسراييل, Label: B-ORGANIZATION, Score: 0.9913205504417419
# Entity: مجلس, Label: B-ORGANIZATION, Score: 0.9980165958404541
# Entity: الامن, Label: I-ORGANIZATION, Score: 0.9970507621765137
# Entity: الدولي, Label: I-ORGANIZATION, Score: 0.9895915389060974
# Entity: غزة, Label: B-LOCATION, Score: 0.9981685876846313
# Entity: المملكة, Label: B-ORGANIZATION, Score: 0.9865422248840332
# Entity: عبد, Label: B-PERSON, Score: 0.9935058355331421
# Entity: الفتاح, Label: I-PERSON, Score: 0.9977335929870605
# Entity: السيسي, Label: I-PERSON, Score: 0.998599112033844
# Entity: وحكومة, Label: B-ORGANIZATION, Score: 0.949418842792511
# Entity: مصر, Label: I-ORGANIZATION, Score: 0.6352948546409607
# Entity: قطاع, Label: B-LOCATION, Score: 0.9975332021713257
# Entity: غزة, Label: I-LOCATION, Score: 0.9931434392929077
# Entity: فيصل, Label: B-PERSON, Score: 0.9820374250411987
# Entity: بن, Label: I-PERSON, Score: 0.9951735138893127
# Entity: فرحان, Label: I-PERSON, Score: 0.9969156980514526
# Entity: بن, Label: I-PERSON, Score: 0.9869469404220581
# Entity: عبد, Label: I-PERSON, Score: 0.9960505366325378
# Entity: الله, Label: I-PERSON, Score: 0.9937238097190857
# Entity: القاهرة, Label: B-LOCATION, Score: 0.9962775111198425
# Entity: المملكة, Label: B-ORGANIZATION, Score: 0.9517402648925781
# Entity: قمة, Label: B-EVENT, Score: 0.7680076956748962
# Entity: القاهرة, Label: I-EVENT, Score: 0.6746972799301147
# Entity: للسلام, Label: I-EVENT, Score: 0.7357789278030396
# Entity: غزة, Label: B-LOCATION, Score: 0.9969769716262817
# Entity: محمد, Label: B-PERSON, Score: 0.974435567855835
# Entity: بن, Label: I-PERSON, Score: 0.9938647150993347
# Entity: سلمان, Label: I-PERSON, Score: 0.996117353439331
# Entity: بن, Label: I-PERSON, Score: 0.9416683912277222
# Entity: عبد, Label: I-PERSON, Score: 0.9942849278450012
# Entity: العزيز, Label: I-PERSON, Score: 0.9739050269126892
# Entity: مجلس, Label: B-ORGANIZATION, Score: 0.9775180220603943
# Entity: الوزراء, Label: I-ORGANIZATION, Score: 0.5891041159629822
# Entity: بوتين, Label: B-PERSON, Score: 0.9936705827713013
# Entity: فلسطين, Label: B-LOCATION, Score: 0.9967458248138428
# Entity: قطاع, Label: B-LOCATION, Score: 0.9980269074440002
# Entity: غزة, Label: I-LOCATION, Score: 0.99566251039505

# %%
matched_nationalities = set()

# Replace "أ" with "ا"
text = text.replace("أ", "ا")

# Replace "إ" with "ا"
text = text.replace("إ", "ا")

# Define the part of the word you want to search for
for element in nationalities_lst:
    search_part = element

    # Create a regex pattern to find the search part
    pattern = re.compile(r"\b\w*" + re.escape(search_part) + r"\w*\b")

    # Find all the matched words in the sentence
    matched_words = re.findall(pattern, text)

    # Check if any words are found
    if matched_words:
        for word in matched_words:
            matched_nationalities.add(word)
    else:
        continue

# %%
matched_nationalities
# Out:
# {'اسرائيل', 'السعودي', 'السعودية', 'المصري', 'المصرية'}

# %%
# Check if the word is a nationality
for result in matched_nationalities:
    text = text.replace(result, colored(result, on_color='on_green'))

for result in combined_results:
    if result['label'] == "B-PERSON" or result['label'] == "I-PERSON":
        text = text.replace(result['word'], colored(result['word'], on_color='on_blue'))
    elif result['label'] == "B-LOCATION" or result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
    elif result['label'] == "B-ORGANIZATION" or result['label'] == "I-ORGANIZATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_red'))
    elif result['label'] == "B-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_yellow'))
    elif result['label'] == "I-EVENT":
        text = text.replace(result['word'], colored(result['word'], on_color='on_magenta'))
    elif result['label'] == "I-LOCATION":
        text = text.replace(result['word'], colored(result['word'], on_color='on_green'))
#     elif result['label'] == "I-DATE" or result['label'] == "B-DATE":
#         if result["word"] == "من":
#             continue
#         else:
#             text = text.replace(result['word'], colored(result['word'], on_color='on_white'))
            
for i in dates:
    text = text.replace(i, colored(i, on_color='on_white'))
# Print or return the colored sentence
print(text)
# Out:
# اكد وزير الخارجية السعودي، اليوم السبت، ان الاحداث الماساوية في فلسطين تحتم علينا التحرك العاجل لوقف اطلاق النار، معلناً رفض بلاده بشكل قاطع تهجير الفلسطينيين من اراضيهم. وطالب خلال كلمته في قمة السلام بالقاهرة بفتح فوري لممرات انسانية آمنة الى غزة، داعياً المجتمع الدولي الى الزام اسرائيل بالتقيد بالقانون الدولي. وقال خلال مشاركته في القمة: «نرفض محاولات التهجير القسري للفلسطينيين، واننا نعرب عن خيبة املنا في عجز مجلس الامن الدولي عن اتخاذ موقف حيال الازمة الحالية في غزة حتى الآن، ونطالب بفتح فوري لممرات انسانية آمنة». وعبر وزير الخارجية السعودية عن امله في ان تسهم هذه القمة في تحرك حاسم للمجتمع الدولي لايجاد حل لهذه الازمة، مؤكداً على «تمسك المملكة بالسلام خياراً استراتيجياً عبر الوقوف مع الشعب الفلسطيني لاستعادة حقوقه المشروعة». وقدم وزير الخارجية السعودي الشكر للرئيس المصري عبد الفتاح السيسي، وحكومة مصر، على الجهود المبذولة «لتعزيز التنسيق والتشاور الاقليمي والدولي تجاه ما نشهده من تطورات خطيرة في قطاع غزة». كان الامير فيصل بن فرحان بن عبد الله وزير الخارجية السعودي، وصل اليوم الى العاصمة المصرية القاهرة، لترؤس وفد المملكة المشارك في قمة القاهرة للسلام، والمنعقدة بشان مناقشة الصراع في غزة ومحيطها، ومستقبل القضية الفلسطينية، وذلك نيابةً عن الامير محمد بن سلمان بن عبد العزيز ولي العهد رئيس مجلس الوزراء كما شارك بوتين. ويشارك في القمة عدد من الدول والمنظمات الدولية لبحث تطورات الاوضاع الراهنة في فلسطين، والعمل على حماية المدنيين في قطاع غزة المُحاصر، والسماح بفتح ممرات آمنة، وادخال المساعدات الانسانية والطبية والغذائية

# %%
sentence = "أكد وزير الخارجية السعودي، اليوم السبت، أن الأحداث المأساوية في فلسطين تحتم علينا التحرك العاجل لوقف إطلاق النار، معلناً رفض بلاده بشكل قاطع تهجير الفلسطينيين من أراضيهم. وطالب خلال كلمته في قمة السلام بالقاهرة بفتح فوري لممرات إنسانية آمنة إلى غزة، داعياً المجتمع الدولي إلى إلزام إسرائيل بالتقيد بالقانون الدولي. وقال خلال مشاركته في القمة: «نرفض محاولات التهجير القسري للفلسطينيين، وإننا نعرب عن خيبة أملنا في عجز مجلس الأمن الدولي عن اتخاذ موقف حيال الأزمة الحالية في غزة حتى الآن، ونطالب بفتح فوري لممرات إنسانية آمنة». وعبر وزير الخارجية السعودية عن أمله في أن تسهم هذه القمة في تحرك حاسم للمجتمع الدولي لإيجاد حل لهذه الأزمة، مؤكداً على «تمسك المملكة بالسلام خياراً استراتيجياً عبر الوقوف مع الشعب الفلسطيني لاستعادة حقوقه المشروعة». وقدم وزير الخارجية السعودي الشكر للرئيس المصري عبد الفتاح السيسي، وحكومة مصر، على الجهود المبذولة «لتعزيز التنسيق والتشاور الإقليمي والدولي تجاه ما نشهده من تطورات خطيرة في قطاع غزة». كان الأمير فيصل بن فرحان بن عبد الله وزير الخارجية السعودي، وصل اليوم إلى العاصمة المصرية القاهرة، لترؤس وفد المملكة المشارك في قمة القاهرة للسلام، والمنعقدة بشأن مناقشة الصراع في غزة ومحيطها، ومستقبل القضية الفلسطينية، وذلك نيابةً عن الأمير محمد بن سلمان بن عبد العزيز ولي العهد رئيس مجلس الوزراء كما شارك بوتين. ويشارك في القمة عدد من الدول والمنظمات الدولية لبحث تطورات الأوضاع الراهنة في فلسطين، والعمل على حماية المدنيين في قطاع غزة المُحاصر، والسماح بفتح ممرات آمنة، وإدخال المساعدات الإنسانية والطبية والغذائية"

def extract_arabic_dates(text):
    # Define a regex pattern for the date format with a single slash
    pattern = re.compile(r'\b(\d{1,2})\\(\d{1,2})\\(\d{4})\b')

    # Find all matches in the text
    matches = re.findall(pattern, sentence)

    # Format the matches as "١٠\١٠\٢٠٢٣"
    formatted_dates = [f"{day}\\{month}\\{year}" for day, month, year in matches]

    return formatted_dates

# Example usage
# text = " الاجتماع سيكون يوم الخميس الموافق ١٠\١٠\٢٠٢٣ في الساعة ٣ مساءً ويوم الجمعة الموافق ١١\١٠\٢٠٢٣ في الساعة ٣ مساءً."
dates = extract_arabic_dates(sentence)

print(dates)
# Out:
# []

# %%
# Join and return consecutive words with the label "B-PERSON"
joined_persons = []
current_person = []

for entity in combined_results:
    if entity['label'] == 'B-PERSON' or entity['label'] == 'I-PERSON':
        current_person.append(entity['word'])
    elif current_person:
        joined_persons.append(' '.join(current_person))
        current_person = []

# Add the last person if any
if current_person:
    joined_persons.append(' '.join(current_person))

# Print or return the joined persons
print(joined_persons)
# Out:
# ['عبد الفتاح السيسي', 'فيصل بن فرحان بن عبد الله', 'محمد بن سلمان بن عبد العزيز', 'بوتين']

# %%
# Create an empty set
key_words = set()

for i in combined_results:
    if i["label"] != 'B-PRODUCT' and i["label"] != 'I-PRODUCT' and i["label"] != 'B-ORGANIZATION' and i["label"] != "I-DATE" and i["label"] != "B-DATE" and i["label"] != "I-PERSON" and i["label"] != "B-PERSON":
        key_words.add(i["word"])
    else:
        continue
        
for i in dates:
    key_words.add(i)
    
for i in matched_nationalities:
    key_words.add(i)
    
for i in joined_persons:
    key_words.add(i)

# %%
print(key_words)
# Out:
# {'السعودي', 'مصر', 'قطاع', 'المصري', 'الامن', 'قمة', 'محمد بن سلمان بن عبد العزيز', 'اسرائيل', 'بوتين', 'القاهرة', 'السعودية', 'المصرية', 'فيصل بن فرحان بن عبد الله', 'عبد الفتاح السيسي', 'غزة', 'بالقاهرة', 'الدولي', 'الوزراء', 'للسلام', 'فلسطين'}
